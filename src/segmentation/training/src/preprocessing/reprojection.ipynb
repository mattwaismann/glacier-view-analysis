# %%
import os
import read

# %%
dir_path = os.path.join(os.path.expanduser("~"),"Desktop","projects", "glacier-view-segmentation","small_data","nasa_dems")

# %% [markdown]
# ### Reproject training tifs

# %%
#obtain list of tiff names
tifs = next(os.walk(dir_path))[2]
tifs = sorted(tifs)
for i in range(len(tifs)):
    tif = tifs[i]
    read.reproject_raster(os.path.join(dir_path,tif),os.path.join(dir_path,"new_nasa_dems",tif))

# %% [markdown]
# ### Reproject time series tifs

# %%
ts_tifs
# Out:
# ['1984-07-21.tif',
#  '1984-09-07.tif',
#  '1984-09-23.tif',
#  '1984-11-03.tif',
#  '1985-06-22.tif',
#  '1985-07-17.tif',
#  '1985-08-18.tif',
#  '1985-10-05.tif',
#  '1986-02-17.tif',
#  '1986-05-01.tif',
#  '1986-06-25.tif',
#  '1986-07-04.tif',
#  '1986-08-21.tif',
#  '1986-09-06.tif',
#  '1986-09-13.tif',
#  '1986-09-29.tif',
#  '1987-03-17.tif',
#  '1987-08-08.tif',
#  '1987-08-24.tif',
#  '1988-04-20.tif',
#  '1989-04-07.tif',
#  '1989-05-25.tif',
#  '1989-07-03.tif',
#  '1989-08-13.tif',
#  '1989-10-23.tif',
#  '1990-03-16.tif',
#  '1990-04-10.tif',
#  '1990-04-26.tif',
#  '1990-05-12.tif',
#  '1990-05-19.tif',
#  '1990-06-29.tif',
#  '1990-07-06.tif',
#  '1990-07-22.tif',
#  '1990-08-23.tif',
#  '1991-06-23.tif',
#  '1992-05-17.tif',
#  '1992-06-09.tif',
#  '1992-07-04.tif',
#  '1992-09-13.tif',
#  '1993-03-17.tif',
#  '1993-04-18.tif',
#  '1993-04-25.tif',
#  '1993-05-11.tif',
#  '1993-05-27.tif',
#  '1993-06-28.tif',
#  '1993-07-07.tif',
#  '1993-07-14.tif',
#  '1993-10-11.tif',
#  '1994-06-15.tif',
#  '1994-08-02.tif',
#  '1994-08-11.tif',
#  '1994-08-18.tif',
#  '1994-10-14.tif',
#  '1995-04-24.tif',
#  '1995-05-01.tif',
#  '1995-06-11.tif',
#  '1995-06-27.tif',
#  '1995-07-04.tif',
#  '1995-07-20.tif',
#  '1995-09-15.tif',
#  '1996-03-25.tif',
#  '1996-04-10.tif',
#  '1996-05-03.tif',
#  '1996-05-12.tif',
#  '1996-05-19.tif',
#  '1996-05-28.tif',
#  '1996-07-15.tif',
#  '1996-08-16.tif',
#  '1996-09-08.tif',
#  '1997-04-13.tif',
#  '1997-05-22.tif',
#  '1997-05-31.tif',
#  '1997-06-07.tif',
#  '1997-06-23.tif',
#  '1997-07-02.tif',
#  '1997-08-03.tif',
#  '1998-07-12.tif',
#  '1998-07-28.tif',
#  '1998-10-09.tif',
#  '1999-07-16.tif',
#  '1999-07-31.tif',
#  '1999-08-01.tif',
#  '2000-02-09.tif',
#  '2000-04-13.tif',
#  '2000-05-31.tif',
#  '2000-06-23.tif',
#  '2000-08-10.tif',
#  '2000-08-26.tif',
#  '2000-10-29.tif',
#  '2001-06-26.tif',
#  '2001-08-13.tif',
#  '2002-03-18.tif',
#  '2002-04-03.tif',
#  '2002-04-10.tif',
#  '2002-05-05.tif',
#  '2002-07-08.tif',
#  '2002-07-31.tif',
#  '2002-10-03.tif',
#  '2003-03-05.tif',
#  '2003-03-12.tif',
#  '2003-04-13.tif',
#  '2003-05-08.tif',
#  '2003-07-10.tif',
#  '2003-07-18.tif',
#  '2003-08-11.tif',
#  '2003-08-28.tif',
#  '2003-09-05.tif',
#  '2003-09-29.tif',
#  '2004-02-27.tif',
#  '2004-03-23.tif',
#  '2004-04-15.tif',
#  '2004-05-10.tif',
#  '2004-05-18.tif',
#  '2004-06-03.tif',
#  '2004-06-18.tif',
#  '2004-07-13.tif',
#  '2004-08-05.tif',
#  '2004-08-06.tif',
#  '2004-08-14.tif',
#  '2004-08-22.tif',
#  '2004-09-07.tif',
#  '2004-10-17.tif',
#  '2005-02-13.tif',
#  '2005-03-17.tif',
#  '2005-04-27.tif',
#  '2005-05-05.tif',
#  '2005-06-05.tif',
#  '2005-06-06.tif',
#  '2005-07-08.tif',
#  '2005-08-08.tif',
#  '2005-08-09.tif',
#  '2005-08-16.tif',
#  '2006-02-16.tif',
#  '2006-02-25.tif',
#  '2006-03-29.tif',
#  '2006-05-15.tif',
#  '2006-06-08.tif',
#  '2006-06-09.tif',
#  '2006-07-02.tif',
#  '2006-07-03.tif',
#  '2006-07-11.tif',
#  '2006-08-28.tif',
#  '2006-09-13.tif',
#  '2007-02-28.tif',
#  '2007-04-17.tif',
#  '2007-05-02.tif',
#  '2007-05-18.tif',
#  '2007-05-19.tif',
#  '2007-06-19.tif',
#  '2007-07-22.tif',
#  '2007-08-15.tif',
#  '2008-02-22.tif',
#  '2008-05-20.tif',
#  '2008-05-28.tif',
#  '2008-05-29.tif',
#  '2008-08-17.tif',
#  '2009-02-24.tif',
#  '2009-02-25.tif',
#  '2009-04-14.tif',
#  '2009-04-29.tif',
#  '2009-04-30.tif',
#  '2009-05-16.tif',
#  '2009-05-31.tif',
#  '2009-06-01.tif',
#  '2009-06-08.tif',
#  '2009-06-24.tif',
#  '2009-07-02.tif',
#  '2009-07-03.tif',
#  '2009-07-10.tif',
#  '2009-07-11.tif',
#  '2009-08-03.tif',
#  '2009-08-04.tif',
#  '2009-09-05.tif',
#  '2009-09-29.tif',
#  '2009-10-14.tif',
#  '2010-02-20.tif',
#  '2010-04-09.tif',
#  '2010-04-24.tif',
#  '2010-05-27.tif',
#  '2010-07-30.tif',
#  '2010-08-14.tif',
#  '2010-08-15.tif',
#  '2010-09-07.tif',
#  '2010-09-16.tif',
#  '2010-10-25.tif',
#  '2011-03-02.tif',
#  '2011-03-11.tif',
#  '2011-03-19.tif',
#  '2011-04-19.tif',
#  '2011-04-27.tif',
#  '2011-04-28.tif',
#  '2011-05-14.tif',
#  '2011-05-29.tif',
#  '2011-05-30.tif',
#  '2011-06-06.tif',
#  '2011-06-07.tif',
#  '2012-04-05.tif',
#  '2012-06-24.tif',
#  '2012-07-19.tif',
#  '2012-08-04.tif',
#  '2012-10-23.tif',
#  '2013-03-07.tif',
#  '2013-05-27.tif',
#  '2013-06-11.tif',
#  '2013-06-12.tif',
#  '2013-07-14.tif',
#  '2013-07-29.tif',
#  '2013-07-30.tif',
#  '2013-08-06.tif',
#  '2013-08-14.tif',
#  '2013-10-17.tif',
#  '2013-10-26.tif',
#  '2013-11-02.tif',
#  '2014-02-22.tif',
#  '2014-02-23.tif',
#  '2014-03-02.tif',
#  '2014-03-03.tif',
#  '2014-03-26.tif',
#  '2014-04-03.tif',
#  '2014-05-05.tif',
#  '2014-05-22.tif',
#  '2014-07-01.tif',
#  '2014-07-16.tif',
#  '2014-08-01.tif',
#  '2014-08-02.tif',
#  '2014-10-13.tif',
#  '2014-11-13.tif',
#  '2015-02-01.tif',
#  '2015-03-05.tif',
#  '2015-04-23.tif',
#  '2015-05-01.tif',
#  '2015-05-16.tif',
#  '2015-05-17.tif',
#  '2015-05-25.tif',
#  '2015-08-04.tif',
#  '2015-08-13.tif',
#  '2015-09-13.tif',
#  '2015-09-22.tif',
#  '2016-03-31.tif',
#  '2016-04-08.tif',
#  '2016-05-03.tif',
#  '2016-05-10.tif',
#  '2016-05-11.tif',
#  '2016-05-19.tif',
#  '2016-07-30.tif',
#  '2016-08-31.tif',
#  '2016-10-01.tif',
#  '2016-10-09.tif',
#  '2016-10-26.tif',
#  '2016-11-18.tif',
#  '2017-02-06.tif',
#  '2017-02-23.tif',
#  '2017-03-10.tif',
#  '2017-03-11.tif',
#  '2017-04-11.tif',
#  '2017-04-12.tif',
#  '2017-05-05.tif',
#  '2017-05-06.tif',
#  '2017-05-29.tif',
#  '2017-08-09.tif',
#  '2017-09-11.tif',
#  '2017-09-18.tif',
#  '2017-10-12.tif',
#  '2017-10-28.tif',
#  '2017-11-14.tif',
#  '2018-01-08.tif',
#  '2018-02-02.tif',
#  '2018-02-09.tif',
#  '2018-02-10.tif',
#  '2018-02-17.tif',
#  '2018-02-18.tif',
#  '2018-03-29.tif',
#  '2018-03-30.tif',
#  '2018-04-07.tif',
#  '2018-04-15.tif',
#  '2018-05-08.tif',
#  '2018-05-16.tif',
#  '2018-05-17.tif',
#  '2018-07-03.tif',
#  '2018-07-04.tif',
#  '2018-07-19.tif',
#  '2018-07-27.tif',
#  '2018-07-28.tif',
#  '2018-08-05.tif',
#  '2018-09-05.tif',
#  '2018-09-06.tif',
#  '2018-09-13.tif',
#  '2018-09-21.tif',
#  '2018-09-29.tif',
#  '2018-09-30.tif',
#  '2018-10-08.tif',
#  '2019-02-20.tif',
#  '2019-02-28.tif',
#  '2019-03-01.tif',
#  '2019-03-25.tif',
#  '2019-04-01.tif',
#  '2019-04-02.tif',
#  '2019-05-11.tif',
#  '2019-05-12.tif',
#  '2019-05-27.tif',
#  '2019-06-13.tif',
#  '2019-06-20.tif',
#  '2019-06-28.tif',
#  '2019-06-29.tif',
#  '2019-07-07.tif',
#  '2019-07-30.tif',
#  '2019-07-31.tif',
#  '2019-08-07.tif',
#  '2019-08-08.tif',
#  '2019-08-16.tif',
#  '2019-09-08.tif',
#  '2019-09-09.tif',
#  '2019-09-17.tif',
#  '2019-10-03.tif',
#  '2019-10-26.tif',
#  'USGS_DEM.tif']

# %%
old_folder = 'old' #folder name that has the unprojected time series
folders = next(os.walk(r"C:\Users\mattw\Desktop\projects\glacier_segmentation\time_series\{}".format(old_folder)))[1]
for folder in folders:
    ts_tifs = next(os.walk(r"C:\Users\mattw\Desktop\projects\glacier_segmentation\time_series\{}\{}".format(old_folder,folder)))[2]
    os.makedirs(r"C:\Users\mattw\Desktop\projects\glacier_segmentation\time_series\new\{}".format(folder))
    for tif in ts_tifs:
        #reprojecting each tif in each time series to lat-long
        read.reproject_raster(r"C:\Users\mattw\Desktop\projects\glacier_segmentation\time_series\{old}\{folder}\{tif}".format(old = old_folder,folder = folder,tif = tif),r"C:\Users\mattw\Desktop\projects\glacier_segmentation\time_series\new\{folder}\{tif}".format(folder = folder, tif = tif))
        continue
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-10-f7cda52788a1> in <module>
#       3 for folder in folders:
#       4     ts_tifs = next(os.walk(r"C:\Users\mattw\Desktop\projects\glacier_segmentation\time_series\{}\{}".format(old_folder,folder)))[2]
# ----> 5     os.makedirs(r"C:\Users\mattw\Desktop\projects\glacier_segmentation\time_series\new\{}".format(folder))
#       6     for tif in ts_tifs:
#       7         #reprojecting each tif in each time series to lat-long
#
# ~\Miniconda3\envs\glacier_segmentation\lib\os.py in makedirs(name, mode, exist_ok)
#     221             return
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#     225         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\mattw\\Desktop\\projects\\glacier_segmentation\\time_series\\new\\G006628E45300N'
