# %%
import ee 
from datetime import datetime
import os
import geemap
import geopandas as gpd
from ee_helpers import EePull
import pandas as pd
import importlib

itertools = importlib.import_module('ee_helpers')

# %%
# Trigger the authentication flow
ee.Authenticate()

# Initialize the library
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=lxdBzKG1rlG-4r3gTMX2z96fPzXS0Ihl9uRkoLwfz4s&tc=q10pPc2qVX6OpPfJnOWbpr5z4uqTeLgEL-VJCLjyNFQ&cc=Yvp3Wh96AqaR4SguNjsu1fOSaBPzTQd7z1TzO4y2WIs>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=lxdBzKG1rlG-4r3gTMX2z96fPzXS0Ihl9uRkoLwfz4s&tc=q10pPc2qVX6OpPfJnOWbpr5z4uqTeLgEL-VJCLjyNFQ&cc=Yvp3Wh96AqaR4SguNjsu1fOSaBPzTQd7z1TzO4y2WIs</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1AfJohXmheiRTqkVLMdC9JA6xemm-t8THC-9ytoLPtNOuI6ZHgMAInltf5dc
#
# Successfully saved authorization token.

# %%
data_label = "full_time_series_c02_t1_l2"
batch_num = 1
glacier_view_dir = os.path.join(os.path.expanduser('~'),"Desktop","projects","GlacierView")
log_dir = os.path.join(glacier_view_dir,"src","earth_engine","data","ee_landing_zone",data_label, "logs")
image_dir = os.path.join(glacier_view_dir,"src","earth_engine","data","ee_landing_zone",data_label, "landsat")

# %%
ee_pull = EePull(log_dir, "trient_only")

# %%
glims_bb_path = os.path.join(glacier_view_dir,"src","glims","data","joined_time_series","joined_474_bb.shp")
df = gpd.read_file(glims_bb_path)
df = df[df.glac_id == 'G007026E45991N'] # trient only

# %%
df = df.sample(frac=1).reset_index(drop=True)
n=df.shape[0]
print(n)
# Out:
# 1

# %%
start_date = datetime(1980,1,1)
end_date = datetime(2023,12,31)

# %%
for idx,row in enumerate(df.iterrows()):
    glims_id = row[1].glac_id
    bounding_box = eval(row[1].bboxes)
    out_dir = os.path.join(image_dir,glims_id)
    if not os.path.exists(out_dir):
        os.mkdir(out_dir)
    
    ee_pull.export_landsat_five_images(glims_id,
                                        bounding_box,
                                        start_date,
                                        end_date,
                                        out_dir)
    ee_pull.export_landsat_seven_images(glims_id,
                                        bounding_box,
                                        start_date,
                                        end_date,
                                        out_dir)
    ee_pull.export_landsat_eight_images(glims_id,
                                        bounding_box,
                                        start_date,
                                        end_date,
                                        out_dir)
# Out:
# Number of images in this collection:  613
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cd5221d504a2ac6c3b5b009df35747d7-f98459180ab30d41728cbb4145dbe696:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_1984-04-18_L5_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/95d56a40aec05d4cf6ac1d405e1ebf8a-6f1725ab3ea9a81c280a0cd4f47f4d4a:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_1984-06-21_L5_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c7ec0276feefbce12750a17a42a837f9-aa60491c5cd78da7b20392eb5efe59af:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_1984-08-08_L5_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/efce47e1cd272b5382a47fb9f5e691fa-3d89af0344ca84cf969d2923529d0f16:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_1984-08-24_L5_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4b4839d6a7c0f9d0a590d44d31557ea8-8fa881a25a61c5809fb49e617e0bce54:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_1984-09-09_L5_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9563837146ba14e0af981c608dc4a2c4-93e16a2c2c9f17694c920b44df33ec72:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_1984-09-25_L5_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0907ccf9ddb983e6d919bd7c7e6d9a7c-05c0c49fe3b046c379fd32542c728771:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_1984-10-11_L5_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6aa4e68d87f008ff7671853144f0427e-0be352129864cad08835b57369655e19:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_1984-10-27_L5_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3
getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2022-07-23_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/01404750b33d34715fe84071d5b7c8bf-0f8c9e33ced525c7b777968bce2ec13d:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2022-08-08_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a5f25c1f154605ff1e1c0d7d674b5627-54c064c1e64cafc31d30af0e4c433479:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2022-08-24_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d3c27af8ca2242d265d257dee0851bac-00d1eab3e286ce01d9fb79ae982772f2:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2022-09-09_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/85993ad1c7c5b0913ca0bc930b337e6d-8d34d127f7a4628266e494da2f1df19a:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2022-09-25_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a3beccd1bb6078a6b1194b39882ebf16-8709ef2aad49d32ae69a15818921262f:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2022-10-11_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7c482b6f00019899c4081ac12d885e36-2ba5e1507aa5b9511403893af43ffa02:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2022-10-27_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/86eda3ae7730fd5d5459e8719f8e50b6-82fb7efa89bcbea6dd619610bc6535ad:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2022-11-12_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/abafb0aaeacbdb82d9d08bdcf2012840-3de5284c0f4f19c6b6e20e79f3c152fb:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-01-31_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/849d453747ff99e317566fda1c4c0233-45072048b3666d6f0f4cfde7d07969a8:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-02-16_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5b576fb16f5d5984b9ca7f7c773731d2-0612f40b5beceab163cc6265bb34d15d:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-03-04_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/429994b6fc6623cac68930ff85f04a65-e179fb1542b133abb4e32eecd073040b:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-03-20_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bf6b3545284184a0ecdcbaf506454f38-aac64f676d46bc0de94c2e772a518b1d:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-04-05_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/adcc846ca795a728c0dc56912cc7b2b2-d8b3c1202f025b8561011f6f765f8d21:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-04-21_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cf108da86fda8711df779a9428d1c07c-d8d3c49a7f60b32154fd755975703426:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-05-23_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/893e123bf4edeb35728d5c173b10420b-83d372ef34bc305dd0804247235bc058:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-06-08_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7ea606b34e06d0f547e2fd4284ce95d1-9cc59f595ba3b4222fdc304b5c95dc69:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-06-24_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d1ef01792043ba7561eb2edbb43b1016-a80613db5ba4d3336884556216bdfb53:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-07-10_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a75875fca4569d6981954f95baa6993c-fc7544476456f86ff0d90212e159e494:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-07-26_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f0814686255273102aefdd0c7c6f74fa-0bf0e42de623cb7770ea6eb1efa76153:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-08-11_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/62d1c8bfc5feb11808c79df6959b7cb7-ead4f02d0b4aba032dc3deda44091258:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-09-12_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bf180bdb959a2f241d03bf53826d673d-b80f5379dde6bd568d8f0abb51fa5f68:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-09-28_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/fffe04e4b49f8332b034ec3273198c3e-aca25f340beb83b2b185eb8c71fa1c56:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-10-14_L8_C02_T1_L2_SR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ba32470d0659eafa2549fbff2ef99ca2-ca4769df626bfb2fd177ac9db768485f:getPixels
# Please wait ...
# Data downloaded to /Users/mattw/Desktop/projects/GlacierView/src/earth_engine/data/ee_landing_zone/full_time_series_c02_t1_l2/landsat/G007026E45991N/G007026E45991N_2023-11-15_L8_C02_T1_L2_SR.tif

# %%
# log_df_1 = pd.read_csv("...")
# done_in_batch_1 = [row.split(": ")[1] for row in log_df_1.iloc[:,1]]
# log_df_2 = pd.read_csv("...")
# done_in_batch_2 = [row.split(": ")[1] for row in log_df_2.iloc[:,1]]
# b1 = set(done_in_batch_1)
# b2 = set(done_in_batch_2)
# print(
#     " Batch 1 has {} glaciers\n".format(len(b1)),
#     "Batch 2 has {} glaciers\n".format(len(b2)),
#     "Therefore {} glaciers remain".format(474-(len(b1) + len(b2) - 4 )))
# ...
# df = df[~df.glac_id.isin(set.union(b1,b2))]
